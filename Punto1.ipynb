# %%
import grafica as gr
import numpy as np

# %%
def funcion(x,y):
    return 6/(3*𝑥**2+2*𝑦**2+1)
def derivadax(x,y):
    return -36*𝑥/(3*𝑥**2 + 2*𝑦**2 + 1)**2
def derivaday(x,y):
    return -24*y/(3*𝑥**2 + 2*𝑦**2 + 1)**2
alfa=0.1
x=-2
y=3
print(funcion(x,y))
print(derivadax(x,y),derivaday(x,y))
#aumentar y disminuir x para que la funcion crezca
#disminuir y y aumentar x para que la funcion disminuya
#modulo=np.sqrt(derivadax(x,y)**2+derivaday(x,y)**2)
#print(modulo)
#def coseno(x,y):
#    return derivadax(x,y)/modulo
#def seno(x,y):
#    return derivaday(x,y)/modulo

#print(coseno(x,y), seno(x,y))
#para crecer
print(derivadax(x,y)+alfa*derivadax(x,y),derivaday(x,y)+alfa*derivaday(x,y))
#para decrecer
#print(derivadax(x,y)-alfa*derivadax(x,y),derivaday(x,y)-alfa*derivaday(x,y))
# Out:
# 0.1935483870967742
# 0.07492195629552549 -0.07492195629552549
# 0.08241415192507803 -0.08241415192507803
# 5.8029298212285845

# %%
import numpy as np
import grafica as gr
import math

#z =  6/(3*𝑥**2+2*𝑦**2+1);

[x, y, h] = gr.graficoGradiente(3)

# z = 3*x**2 + y**2
# PtoAnt = [x, y, z]
# x = x-1  
# y = y-2  #cambiamos x e y
# z = 3*x**2 + y**2;
# graficarPaso(PtoAnt, [x, y, z], h)

alfa = 0.2
MAX_ITE = 100  
ite = 1
z = 1
z_new = 6/(3*𝑥**2+2*𝑦**2+1)

while ((ite<MAX_ITE) and (math.fabs(z - z_new)>0.0001)):
    z = z_new
    PtoAnt = [x, y, z]
    grad_x = -36*𝑥/(3*𝑥**2 + 2*𝑦**2 + 1)**2   # derivada respecto de x
    grad_y = -24*y/(3*𝑥**2 + 2*𝑦**2 + 1)**2  # derivada respecto de y
    
    x = x - alfa * grad_x
    y = y - alfa * grad_y
    z_new = 6/(3*𝑥**2+2*𝑦**2+1)
    
    gr.graficarPaso(PtoAnt, [x, y, z_new], h)
    ite = ite + 1
# Out:
# C:\Users\Josefina Medina\anac\lib\site-packages\matplotlib\figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-fb026938b189> in <module>()
#       5 #z =  6/(3*𝑥**2+2*𝑦**2+1);
#       6
# ----> 7 [x, y, h] = gr.graficoGradiente(3)
#       8
#       9 # z = 3*x**2 + y**2
#
# ~\Documents\FISICA FACULTAD\CUARTO\deep learning\03_CombinadorLineal\grafica.py in graficoGradiente(nroFuncion)
#     182     aux.remove()
#     183
# --> 184     return([coord[0][0], coord[0][1], [ax, ax1]])
#     185
#     186 def graficarPaso(PtoAnt, PtoAct, h):
#
# IndexError: list index out of range
